# %%
from config import AppConfig
from app_runner import AppRunner
from ui import show_ui

cfg = AppConfig()
runner = AppRunner(cfg)
runner.start()

built, ui_loop = show_ui(cfg, runner, ui_hz=10.0)
# Out:
# [1768749736.6s] Runner: started
# VBox(children=(HBox(children=(VBox(children=(HTML(value='Camera: <b>DISCONNECTED</b>'), HTML(value='Mount: <b>…
